# %%
pip install opencv-python
# Out:
# Collecting opencv-python
#   Downloading opencv_python-4.6.0.66-cp36-abi3-win_amd64.whl (35.6 MB)
#      --------------------------------------- 35.6/35.6 MB 10.7 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.14.5 in c:\users\asus\anaconda3\lib\site-packages (from opencv-python) (1.21.5)
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.6.0.66
# Note: you may need to restart the kernel to use updated packages.

# %%
# importing libraries
import cv2
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
# reading the image data from desired directory
img = cv2.imread("dataverse_files\HAM10000_segmentations_lesion_tschandl\HAM10000_segmentations_lesion_tschandl\ISIC_0024306_segmentation.png")
img.shape
# Out:
# (450, 600, 3)

# %%
# reading the image data from desired directory
img = cv2.imread("dataverse_files\HAM10000_segmentations_lesion_tschandl\HAM10000_segmentations_lesion_tschandl\ISIC_0025279_segmentation.png")
img.shape
# Out:
# (450, 600, 3)

# %%
plt.imshow(img)

# %%
  
# counting the number of pixels
number_of_white_pix = np.sum(img == 255)
number_of_black_pix = np.sum(img == 0)
  
print('Number of white pixels:', number_of_white_pix)
print('Number of black pixels:', number_of_black_pix)
# Out:
# Number of white pixels: 31167
# Number of black pixels: 778833

# %%
import glob

# %%
basepath = "dataverse_files\HAM10000_segmentations_lesion_tschandl\HAM10000_segmentations_lesion_tschandl\\"

path = glob.glob(basepath+"*.png")

# %%
ratio = []
for img in path:
    n = cv2.imread(img)
    wp=np.sum(n == 255)
    bp=np.sum(n == 0)
    ratio.append(wp/(wp+bp))

# %%
ratio
# Out:
# [0.34277407407407406,
#  0.41682592592592593,
#  0.3700037037037037,
#  0.3564074074074074,
#  0.24078518518518519,
#  0.2946888888888889,
#  0.4305333333333333,
#  0.10871851851851852,
#  0.10629629629629629,
#  0.08441851851851852,
#  0.44174074074074077,
#  0.36368518518518517,
#  0.21752222222222223,
#  0.2041814814814815,
#  0.3228962962962963,
#  0.11850370370370371,
#  0.12372962962962963,
#  0.3327888888888889,
#  0.1318851851851852,
#  0.334762962962963,
#  0.075,
#  0.2796,
#  0.4391148148148148,
#  0.09427777777777778,
#  0.2361925925925926,
#  0.2640222222222222,
#  0.29005555555555557,
#  0.3609703703703704,
#  0.2949148148148148,
#  0.04974074074074074,
#  0.19284444444444446,
#  0.18372962962962963,
#  0.28788148148148146,
#  0.09848518518518519,
#  0.22266666666666668,
#  0.1771222222222222,
#  0.23813333333333334,
#  0.32589259259259257,
#  0.07089259259259259,
#  0.38317407407407406,
#  0.17383703703703704,
#  0.16967037037037036,
#  0.2527740740740741,
#  0.40504814814814816,
#  0.11878148148148149,
#  0.4464111111111111,
#  0.07402222222222223,
#  0.15434074074074075,
#  0.33145555555555556,
#  0.12561851851851852,
#  0.2354851851851852,
#  0.4001222222222222,
#  0.17474814814814815,
#  0.3717925925925926,
#  0.056462962962962965,
#  0.6127925925925926,
#  0.404,
#  0.09344444444444444,
#  0.11858518518518518,
#  0.5786814814814815,
#  0.15175925925925926,
#  0.0565962962962963,
#  0.3301851851851852,
#  0.23061851851851853,
#  0.24062962962962964,
#  0.6605185185185185,
#  0.3501518518518518,
#  0.0981962962962963,
#  0.28205925925925923,
#  0.017066666666666667,
#  0.10297777777777778,
#  0.07518888888888889,
#  0.0056962962962962965,
#  0.20701111111111112,
#  0.1539111111111111,
#  0.7155592592592592,
#  0.29464074074074076,
#  0.3491111111111111,
#  0.09515555555555555,
#  0.04735185185185185,
#  0.2836185185185185,
#  0.02765925925925926,
#  0.5888148148148148,
#  0.03974814814814815,
#  0.42575555555555555,
#  0.01849259259259259,
#  0.34154814814814816,
#  0.07495185185185185,
#  0.46758518518518516,
#  0.47023703703703706,
#  0.06319629629629629,
#  0.4784481481481481,
#  0.07985555555555555,
#  0.21907037037037036,
#  0.7240037037037037,
#  0.24951851851851853,
#  0.0329,
#  0.12078888888888889,
#  0.05248888888888889,
#  0.1330148148148148,
#  0.11571111111111111,
#  0.07955925925925926,
#  0.07221111111111111,
#  0.037314814814814815,
#  0.11061851851851852,
#  0.03787777777777778,
#  0.16544074074074075,
#  0.16552962962962964,
#  0.2654666666666667,
#  0.6384555555555556,
#  0.015396296296296297,
#  0.12552962962962963,
#  0.0581,
#  0.09814814814814815,
#  0.2137962962962963,
#  0.35081111111111113,
#  0.19362222222222222,
#  0.12414444444444445,
#  0.9859740740740741,
#  0.14844074074074073,
#  0.5258037037037037,
#  0.3454740740740741,
#  0.17225185185185185,
#  0.48002222222222224,
#  0.16971851851851852,
#  0.07618148148148148,
#  0.05932962962962963,
#  0.09398888888888889,
#  0.13822222222222222,
#  0.11338888888888889,
#  0.13327407407407407,
#  0.04625925925925926,
#  0.5001,
#  0.1355925925925926,
#  0.27263333333333334,
#  0.3197888888888889,
#  0.20257777777777777,
#  0.13427037037037037,
#  0.18254074074074075,
#  0.13955185185185184,
#  0.2126925925925926,
#  0.10627777777777778,
#  0.3143740740740741,
#  0.7542444444444445,
#  0.5925370370370371,
#  0.5484481481481481,
#  0.24711111111111111,
#  0.2609962962962963,
#  0.7304518518518518,
#  0.07872592592592592,
#  0.19196666666666667,
#  0.4859703703703704,
#  0.624437037037037,
#  0.5565296296296296,
#  0.14577407407407408,
#  0.3000074074074074,
#  0.46525925925925926,
#  0.5235333333333333,
#  0.4495777777777778,
#  0.35751481481481484,
#  0.24703333333333333,
#  0.0836962962962963,
#  0.4636037037037037,
#  0.3545333333333333,
#  0.6367407407407407,
#  0.5614111111111111,
#  0.2582962962962963,
#  0.16064444444444445,
#  0.5077592592592592,
#  0.05522592592592593,
#  0.267,
#  0.25777037037037037,
#  0.08613703703703704,
#  0.15196666666666667,
#  0.3029296296296296,
#  0.12314814814814815,
#  0.491837037037037,
#  0.19593703703703705,
#  0.26664074074074073,
#  0.08285925925925926,
#  0.042837037037037035,
#  0.09662592592592592,
#  0.17927407407407409,
#  0.6743518518518519,
#  0.6060185185185185,
#  0.07540740740740741,
#  0.07412592592592593,
#  0.6716777777777778,
#  0.35383333333333333,
#  0.04402592592592593,
#  0.26384074074074076,
#  0.21584814814814815,
#  0.20879629629629629,
#  0.15724074074074074,
#  0.0924962962962963,
#  0.1887185185185185,
#  0.11354814814814815,
#  0.1517814814814815,
#  0.5746111111111111,
#  0.23256296296296297,
#  0.1509111111111111,
#  0.2316814814814815,
#  0.26138518518518516,
#  0.18408518518518519,
#  0.36385925925925927,
#  0.42441111111111113,
#  0.4073259259259259,
#  0.2750518518518518,
#  0.16474814814814814,
#  0.13131851851851853,
#  0.32335555555555556,
#  0.13645925925925925,
#  0.3600259259259259,
#  0.07207037037037037,
#  0.42603703703703705,
#  0.2293814814814815,
#  0.17482962962962964,
#  0.7766037037037037,
#  0.053644444444444446,
#  0.2874481481481482,
#  0.15456666666666666,
#  0.23774444444444445,
#  0.14624074074074075,
#  0.2931185185185185,
#  0.09814074074074074,
#  0.13967407407407406,
#  0.10115185185185185,
#  0.11272222222222222,
#  0.6131703703703704,
#  0.522325925925926,
#  0.10764814814814815,
#  0.2368851851851852,
#  0.9365370370370371,
#  0.4065814814814815,
#  0.09823333333333334,
#  0.0784962962962963,
#  0.03471851851851852,
#  0.40213333333333334,
#  0.49987037037037035,
#  0.36795925925925926,
#  0.358462962962963,
#  0.34208518518518516,
#  0.07084814814814815,
#  0.14387777777777777,
#  0.4690037037037037,
#  0.34242962962962964,
#  0.48485555555555554,
#  0.3733814814814815,
#  0.48081851851851853,
#  0.07537037037037037,
#  0.08410740740740741,
#  0.36291851851851853,
#  0.42765555555555557,
#  0.3867555555555556,
#  0.15172962962962963,
#  0.08407407407407408,
#  0.1864851851851852,
#  0.29407037037037037,
#  0.12866666666666668,
#  0.15422592592592593,
#  0.07732222222222222,
#  0.12894814814814815,
#  0.11432222222222223,
#  0.14944444444444444,
#  0.4122037037037037,
#  0.5511111111111111,
#  0.05795555555555556,
#  0.10675925925925926,
#  0.13182222222222223,
#  0.1681814814814815,
#  0.0831888888888889,
#  0.07965555555555555,
#  0.12253333333333333,
#  0.3176222222222222,
#  0.12238148148148148,
#  0.7754111111111112,
#  0.1444037037037037,
#  0.29765925925925923,
#  0.13211851851851852,
#  0.2258037037037037,
#  0.04730740740740741,
#  0.787737037037037,
#  0.19894074074074075,
#  0.20434814814814814,
#  0.21797037037037037,
#  0.2127148148148148,
#  0.7419703703703704,
#  0.41192962962962965,
#  0.06948518518518519,
#  0.1480037037037037,
#  0.1950074074074074,
#  0.10204074074074074,
#  0.07483333333333334,
#  0.06477407407407407,
#  0.19718518518518519,
#  0.15194814814814814,
#  0.02838148148148148,
#  0.18347777777777777,
#  0.009137037037037037,
#  0.12103703703703704,
#  0.3544481481481481,
#  0.20073333333333335,
#  0.512637037037037,
#  0.26976666666666665,
#  0.07315185185185186,
#  0.5687444444444445,
#  0.06485925925925926,
#  0.028785185185185184,
#  0.2696925925925926,
#  0.022625925925925924,
#  0.17402222222222222,
#  0.4520962962962963,
#  0.009992592592592593,
#  0.45856296296296295,
#  0.19118148148148148,
#  0.22106296296296296,
#  0.18176296296296296,
#  0.5630740740740741,
#  0.07684444444444445,
#  0.28346296296296297,
#  0.142,
#  0.2591851851851852,
#  0.03669259259259259,
#  0.2974222222222222,
#  0.3701740740740741,
#  0.12247037037037037,
#  0.1327,
#  0.09332222222222222,
#  0.06971851851851851,
#  0.192,
#  0.7584222222222222,
#  0.5374444444444444,
#  0.18874814814814814,
#  0.16695185185185185,
#  0.580237037037037,
#  0.08804444444444444,
#  0.4238296296296296,
#  0.15722592592592594,
#  0.47367777777777775,
#  0.29583333333333334,
#  0.1059962962962963,
#  0.21881111111111112,
#  0.8624814814814815,
#  0.13655925925925927,
#  0.312337037037037,
#  0.23324074074074075,
#  0.03211481481481482,
#  0.05612962962962963,
#  0.23328888888888888,
#  0.021003703703703705,
#  0.08629259259259259,
#  0.3830962962962963,
#  0.3931777777777778,
#  0.29734074074074074,
#  0.018455555555555555,
#  0.22896296296296295,
#  0.1671962962962963,
#  0.3795962962962963,
#  0.14964814814814814,
#  0.3641111111111111,
#  0.30164074074074076,
#  0.11105185185185185,
#  0.5034481481481482,
#  0.015662962962962962,
#  0.15405555555555556,
#  0.13053333333333333,
#  0.23203703703703704,
#  0.33873333333333333,
#  0.11687777777777777,
#  0.1810074074074074,
#  0.2946259259259259,
#  0.49495185185185187,
#  0.5696074074074075,
#  0.08067037037037036,
#  0.15948148148148147,
#  0.3282333333333333,
#  0.40424814814814813,
#  0.5022185185185185,
#  0.09848148148148148,
#  0.27978148148148146,
#  0.16661851851851853,
#  0.25227777777777777,
#  0.38174814814814817,
#  0.020896296296296295,
#  0.14838148148148148,
#  0.4442185185185185,
#  0.008837037037037037,
#  0.18037777777777778,
#  0.445937037037037,
#  0.17073333333333332,
#  0.2479111111111111,
#  0.12602222222222223,
#  0.04815185185185185,
#  0.42844814814814813,
#  0.11353333333333333,
#  0.3036,
#  0.008977777777777777,
#  0.0850037037037037,
#  0.12436296296296297,
#  0.25804074074074074,
#  0.3084148148148148,
#  0.05198148148148148,
#  0.08042592592592593,
#  0.2932111111111111,
#  0.15561481481481482,
#  0.3738814814814815,
#  0.1143,
#  0.056433333333333335,
#  0.4480851851851852,
#  0.3285740740740741,
#  0.16477407407407407,
#  0.3766925925925926,
#  0.07445185185185185,
#  0.45413703703703706,
#  0.3031,
#  0.22507407407407407,
#  0.734137037037037,
#  0.2874481481481482,
#  0.40904444444444443,
#  0.07687037037037037,
#  0.3026962962962963,
#  0.09505925925925926,
#  0.06587037037037037,
#  0.30143333333333333,
#  0.25462222222222225,
#  0.1741148148148148,
#  0.5120814814814815,
#  0.35257037037037037,
#  0.18686296296296295,
#  0.4706814814814815,
#  0.09995925925925926,
#  0.06825185185185186,
#  0.07372222222222222,
#  0.06474444444444444,
#  0.06748518518518519,
#  0.25888518518518516,
#  0.1706814814814815,
#  0.4162777777777778,
#  0.4073,
#  0.16844814814814815,
#  0.15887777777777778,
#  0.03394814814814815,
#  0.22605555555555557,
#  0.3431037037037037,
#  0.4562555555555556,
#  0.2042037037037037,
#  0.09285185185185185,
#  0.11107037037037037,
#  0.01737037037037037,
#  0.14557037037037038,
#  0.2763,
#  0.13822592592592592,
#  0.13714074074074073,
#  0.09392592592592593,
#  0.2432777777777778,
#  0.15187777777777778,
#  0.19325185185185184,
#  0.16368148148148148,
#  0.3104074074074074,
#  0.45776666666666666,
#  0.22281851851851853,
#  0.02028148148148148,
#  0.10914444444444445,
#  0.3875,
#  0.4049888888888889,
#  0.2855185185185185,
#  0.24827777777777776,
#  0.20112592592592593,
#  0.2680296296296296,
#  0.09034444444444445,
#  0.13607407407407407,
#  0.04025555555555556,
#  0.05511851851851852,
#  0.07064444444444444,
#  0.15537407407407408,
#  0.5192222222222223,
#  0.023725925925925925,
#  0.24121481481481483,
#  0.19982592592592593,
#  0.10652592592592593,
#  0.01834074074074074,
#  0.18938518518518518,
#  0.7617444444444444,
#  0.11371481481481481,
#  0.3085777777777778,
#  0.3274888888888889,
#  0.35,
#  0.08326666666666667,
#  0.4711925925925926,
#  0.1740925925925926,
#  0.21660740740740742,
#  0.2935333333333333,
#  0.35108518518518517,
#  0.19356296296296296,
#  0.6749185185185185,
#  0.3720333333333333,
#  0.1436962962962963,
#  0.10711111111111112,
#  0.05194074074074074,
#  0.27464814814814814,
#  0.008311111111111111,
#  0.6755444444444444,
#  0.20291481481481483,
#  0.33005555555555555,
#  0.23796666666666666,
#  0.4017851851851852,
#  0.13613703703703703,
#  0.08112592592592592,
#  0.08391851851851852,
#  0.4937037037037037,
#  0.9511925925925926,
#  0.1516222222222222,
#  0.01621111111111111,
#  0.1769074074074074,
#  0.42024814814814815,
#  0.3719037037037037,
#  0.18031111111111112,
#  0.26868888888888887,
#  0.5664962962962963,
#  0.590937037037037,
#  0.15257777777777778,
#  0.1497814814814815,
#  0.24480740740740742,
#  0.3345814814814815,
#  0.17687777777777777,
#  0.16447777777777778,
#  0.6669888888888889,
#  0.4315888888888889,
#  0.12962592592592592,
#  0.4475925925925926,
#  0.2649814814814815,
#  0.13366296296296296,
#  0.21416666666666667,
#  0.06114074074074074,
#  0.024177777777777777,
#  0.2521703703703704,
#  0.16162962962962962,
#  0.01746296296296296,
#  0.23442222222222223,
#  0.19894074074074075,
#  0.9914592592592593,
#  0.2509962962962963,
#  0.1555037037037037,
#  0.09057037037037037,
#  0.5947111111111111,
#  0.2199222222222222,
#  0.06911111111111111,
#  0.6170407407407408,
#  0.2813555555555556,
#  0.07601851851851851,
#  0.1958111111111111,
#  0.06521481481481481,
#  0.34392222222222224,
#  0.061203703703703705,
#  0.14351481481481482,
#  0.33507777777777775,
#  0.1920148148148148,
#  0.4794814814814815,
#  0.03785555555555556,
#  0.3423703703703704,
#  0.0777962962962963,
#  0.1504185185185185,
#  0.3479777777777778,
#  0.1492851851851852,
#  0.6034851851851852,
#  0.02035925925925926,
#  0.011974074074074074,
#  0.4525888888888889,
#  0.13543333333333332,
#  0.1083925925925926,
#  0.41004814814814816,
#  0.22954074074074074,
#  0.08557037037037037,
#  0.30448148148148146,
#  0.1551962962962963,
#  0.5195962962962963,
#  0.16415925925925925,
#  0.11514444444444444,
#  0.44371481481481484,
#  0.6128074074074074,
#  0.06937037037037037,
#  0.0639962962962963,
#  0.14212222222222223,
#  0.04507037037037037,
#  0.32783703703703704,
#  0.2576074074074074,
#  0.5036074074074074,
#  0.44374814814814817,
#  0.5630703703703703,
#  0.22102592592592593,
#  0.5233814814814814,
#  0.14737407407407407,
#  0.10696666666666667,
#  0.2085962962962963,
#  0.2282,
#  0.4260814814814815,
#  0.17514074074074074,
#  0.10325925925925926,
#  0.4333851851851852,
#  0.17407037037037038,
#  0.0806962962962963,
#  0.08202222222222222,
#  0.18022592592592593,
#  0.10514814814814814,
#  0.2007962962962963,
#  0.2003962962962963,
#  0.26851851851851855,
#  0.6880777777777778,
#  0.15207037037037038,
#  0.32404074074074074,
#  0.09587037037037037,
#  0.3168148148148148,
#  0.2345,
#  0.05172962962962963,
#  0.07337777777777778,
#  0.4639185185185185,
#  ...]

# %%
import seaborn as sns
  
# plotting a histogram
ax = sns.distplot(ratio,
                  bins=100,
                  kde=True,
                  #color='none',
                  hist_kws={"linewidth": 15,'alpha':0})
ax.set(xlabel='ratio of pixels', ylabel='Frequency')
 
plt.show()
# Out:
# C:\Users\asus\AppData\Local\Temp\ipykernel_26952\3598722256.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(ratio,

# %% [markdown]
# ### Distribution of each class

# %%
import pandas as pd 

skin_df = pd.read_csv('dataverse_files\HAM10000_metadata')

# %%
skin_df
# Out:
#          lesion_id      image_id     dx dx_type   age     sex localization  \
# 0      HAM_0000118  ISIC_0027419    bkl   histo  80.0    male        scalp
# 1      HAM_0000118  ISIC_0025030    bkl   histo  80.0    male        scalp
# 2      HAM_0002730  ISIC_0026769    bkl   histo  80.0    male        scalp
# 3      HAM_0002730  ISIC_0025661    bkl   histo  80.0    male        scalp
# 4      HAM_0001466  ISIC_0031633    bkl   histo  75.0    male          ear
# ...            ...           ...    ...     ...   ...     ...          ...
# 10010  HAM_0002867  ISIC_0033084  akiec   histo  40.0    male      abdomen
# 10011  HAM_0002867  ISIC_0033550  akiec   histo  40.0    male      abdomen
# 10012  HAM_0002867  ISIC_0033536  akiec   histo  40.0    male      abdomen
# 10013  HAM_0000239  ISIC_0032854  akiec   histo  80.0    male         face
# 10014  HAM_0003521  ISIC_0032258    mel   histo  70.0  female         back
#
#             dataset
# 0      vidir_modern
# 1      vidir_modern
# 2      vidir_modern
# 3      vidir_modern
# 4      vidir_modern
# ...             ...
# 10010  vidir_modern
# 10011  vidir_modern
# 10012  vidir_modern
# 10013  vidir_modern
# 10014  vidir_modern
#
# [10015 rows x 8 columns]

# %%
skin_df['dx'].value_counts()
# Out:
# nv       6705
# mel      1113
# bkl      1099
# bcc       514
# akiec     327
# vasc      142
# df        115
# Name: dx, dtype: int64

# %%
skin_df['image_id_seg'] =skin_df['image_id']+"_segmentation.png"

# %%
skin_df
# Out:
#          lesion_id      image_id     dx dx_type   age     sex localization  \
# 0      HAM_0000118  ISIC_0027419    bkl   histo  80.0    male        scalp
# 1      HAM_0000118  ISIC_0025030    bkl   histo  80.0    male        scalp
# 2      HAM_0002730  ISIC_0026769    bkl   histo  80.0    male        scalp
# 3      HAM_0002730  ISIC_0025661    bkl   histo  80.0    male        scalp
# 4      HAM_0001466  ISIC_0031633    bkl   histo  75.0    male          ear
# ...            ...           ...    ...     ...   ...     ...          ...
# 10010  HAM_0002867  ISIC_0033084  akiec   histo  40.0    male      abdomen
# 10011  HAM_0002867  ISIC_0033550  akiec   histo  40.0    male      abdomen
# 10012  HAM_0002867  ISIC_0033536  akiec   histo  40.0    male      abdomen
# 10013  HAM_0000239  ISIC_0032854  akiec   histo  80.0    male         face
# 10014  HAM_0003521  ISIC_0032258    mel   histo  70.0  female         back
#
#             dataset                   image_id_seg
# 0      vidir_modern  ISIC_0027419_segmentation.png
# 1      vidir_modern  ISIC_0025030_segmentation.png
# 2      vidir_modern  ISIC_0026769_segmentation.png
# 3      vidir_modern  ISIC_0025661_segmentation.png
# 4      vidir_modern  ISIC_0031633_segmentation.png
# ...             ...                            ...
# 10010  vidir_modern  ISIC_0033084_segmentation.png
# 10011  vidir_modern  ISIC_0033550_segmentation.png
# 10012  vidir_modern  ISIC_0033536_segmentation.png
# 10013  vidir_modern  ISIC_0032854_segmentation.png
# 10014  vidir_modern  ISIC_0032258_segmentation.png
#
# [10015 rows x 9 columns]

# %%
df_nv = skin_df[skin_df['dx']=='nv']
df_mel = skin_df[skin_df['dx']=='mel']
df_bkl = skin_df[skin_df['dx']=='bkl']
df_bcc = skin_df[skin_df['dx']=='bcc']
df_akiec = skin_df[skin_df['dx']=='akiec']
df_vasc = skin_df[skin_df['dx']=='vasc']
df_df = skin_df[skin_df['dx']=='df']

# %%
df_nv.shape
# Out:
# (6705, 9)

# %%
df_array = ['nv','mel', 'bkl', 'bcc', 'akiec', 'vasc', 'df']

# %%
def get_proportion_of_whitepixels(img_path):
    n = cv2.imread(img_path)
    wp=np.sum(n == 255)
    bp=np.sum(n == 0)
    return (wp/(wp+bp))

# %%
basepath = "dataverse_files\HAM10000_segmentations_lesion_tschandl\HAM10000_segmentations_lesion_tschandl\\"
proportion_dict = {}
for cl in df_array:
    df= skin_df[skin_df['dx']==cl]
    ratio = []
    for i, row in df.iterrows():
        ratio.append(get_proportion_of_whitepixels(os.path.join(basepath, row['image_id_seg'])))
    proportion_dict[cl] = ratio

# %%
proportion_dict.keys()
# Out:
# dict_keys(['nv', 'mel', 'bkl', 'bcc', 'akiec', 'vasc', 'df'])

# %%
for cl in proportion_dict.keys():
    sns.displot(proportion_dict[cl], kind="kde", fill=True)
    #sns.displot(proportion_dict[cl], bins=100,kde=True, hist_kws={"linewidth": 15,'alpha':0} ) 
    #break;

# %%
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

# %%
plt.figure(figsize=(10,7), dpi= 80)
sns.histplot(proportion_dict['nv'], color="dodgerblue", label='nv',kde=True, hist_kws={'alpha':0}, kde_kws={'linewidth':2})
sns.histplot(proportion_dict['mel'], color="r", label='mel',kde=True, hist_kws={'alpha':0}, kde_kws={'linewidth':2})
sns.histplot(proportion_dict['bkl'], color="g", label='bkl',kde=True, hist_kws={'alpha':0}, kde_kws={'linewidth':2})
sns.histplot(proportion_dict['bcc'], color="yellow", label='bcc',kde=True, hist_kws={'alpha':0}, kde_kws={'linewidth':2})
sns.histplot(proportion_dict['akiec'], color="orange", label='akiec',kde=True, hist_kws={'alpha':0}, kde_kws={'linewidth':2})
sns.histplot(proportion_dict['vasc'], color="pink", label='vasc',kde=True, hist_kws={'alpha':0}, kde_kws={'linewidth':2})
sns.histplot(proportion_dict['df'], color="gold", label='df',kde=True, hist_kws={'alpha':0}, kde_kws={'linewidth':2})
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [34], in <cell line: 2>()
#       1 plt.figure(figsize=(10,7), dpi= 80)
# ----> 2 sns.histplot(proportion_dict['nv'], color="dodgerblue", label='nv',kde=True, hist_kws={'alpha':0}, kde_kws={'linewidth':2})
#       3 sns.histplot(proportion_dict['mel'], color="r", label='mel',kde=True, hist_kws={'alpha':0}, kde_kws={'linewidth':2})
#       4 sns.histplot(proportion_dict['bkl'], color="g", label='bkl',kde=True, hist_kws={'alpha':0}, kde_kws={'linewidth':2})
#
# File ~\anaconda3\envs\tf\lib\site-packages\seaborn\distributions.py:1438, in histplot(data, x, y, hue, weights, stat, bins, binwidth, binrange, discrete, cumulative, common_bins, common_norm, multiple, element, fill, shrink, kde, kde_kws, line_kws, thresh, pthresh, pmax, cbar, cbar_ax, cbar_kws, palette, hue_order, hue_norm, color, log_scale, legend, ax, **kwargs)
#    1427 estimate_kws = dict(
#    1428     stat=stat,
#    1429     bins=bins,
#    (...)
#    1433     cumulative=cumulative,
#    1434 )
#    1436 if p.univariate:
# -> 1438     p.plot_univariate_histogram(
#    1439         multiple=multiple,
#    1440         element=element,
#    1441         fill=fill,
#    1442         shrink=shrink,
#    1443         common_norm=common_norm,
#    1444         common_bins=common_bins,
#    1445         kde=kde,
#    1446         kde_kws=kde_kws,
#    1447         color=color,
#    1448         legend=legend,
#    1449         estimate_kws=estimate_kws,
#    1450         line_kws=line_kws,
#    1451         **kwargs,
#    1452     )
#    1454 else:
#    1456     p.plot_bivariate_histogram(
#    1457         common_bins=common_bins,
#    1458         common_norm=common_norm,
#    (...)
#    1468         **kwargs,
#    1469     )
#
# File ~\anaconda3\envs\tf\lib\site-packages\seaborn\distributions.py:453, in _DistributionPlotter.plot_univariate_histogram(self, multiple, element, fill, common_norm, common_bins, shrink, kde, kde_kws, color, legend, line_kws, estimate_kws, **plot_kws)
#     451     kde_kws["cumulative"] = estimate_kws["cumulative"]
#     452     log_scale = self._log_scaled(self.data_variable)
# --> 453     densities = self._compute_univariate_density(
#     454         self.data_variable,
#     455         common_norm,
#     456         common_bins,
#     457         kde_kws,
#     458         log_scale,
#     459         warn_singular=False,
#     460     )
#     462 # First pass through the data to compute the histograms
#     463 for sub_vars, sub_data in self.iter_data("hue", from_comp_data=True):
#     464
#     465     # Prepare the relevant data
#
# File ~\anaconda3\envs\tf\lib\site-packages\seaborn\distributions.py:315, in _DistributionPlotter._compute_univariate_density(self, data_variable, common_norm, common_grid, estimate_kws, log_scale, warn_singular)
#     304 def _compute_univariate_density(
#     305     self,
#     306     data_variable,
#    (...)
#     313
#     314     # Initialize the estimator object
# --> 315     estimator = KDE(**estimate_kws)
#     317     if set(self.variables) - {"x", "y"}:
#     318         if common_grid:
#
# TypeError: __init__() got an unexpected keyword argument 'linewidth'

# %%
#kwargs = dict()

plt.figure(figsize=(10,7), dpi= 80)
#for cl in proportion_dict.keys():
sns.distplot(proportion_dict['nv'], color="dodgerblue", label='nv',kde=True, hist_kws={'alpha':0}, kde_kws={'linewidth':2})
sns.distplot(proportion_dict['mel'], color="r", label='mel',kde=True, hist_kws={'alpha':0}, kde_kws={'linewidth':2})
sns.distplot(proportion_dict['bkl'], color="g", label='bkl',kde=True, hist_kws={'alpha':0}, kde_kws={'linewidth':2})
sns.distplot(proportion_dict['bcc'], color="yellow", label='bcc',kde=True, hist_kws={'alpha':0}, kde_kws={'linewidth':2})
sns.distplot(proportion_dict['akiec'], color="orange", label='akiec',kde=True, hist_kws={'alpha':0}, kde_kws={'linewidth':2})
sns.distplot(proportion_dict['vasc'], color="pink", label='vasc',kde=True, hist_kws={'alpha':0}, kde_kws={'linewidth':2})
sns.distplot(proportion_dict['df'], color="gold", label='df',kde=True, hist_kws={'alpha':0}, kde_kws={'linewidth':2})
               
#sns.distplot(x2, color="orange", label="SUV", **kwargs)
#sns.distplot(x3, color="deeppink", label="minivan", **kwargs)
#plt.xlim(50,75)
plt.legend()
plt.show()
# Out:
# C:\Users\asus\AppData\Local\Temp\ipykernel_26952\1648813971.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(proportion_dict['nv'], color="dodgerblue", label='nv',kde=True, hist_kws={'alpha':0}, kde_kws={'linewidth':2})
# C:\Users\asus\AppData\Local\Temp\ipykernel_26952\1648813971.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(proportion_dict['mel'], color="r", label='mel',kde=True, hist_kws={'alpha':0}, kde_kws={'linewidth':2})
# C:\Users\asus\AppData\Local\Temp\ipykernel_26952\1648813971.py:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(proportion_dict['bkl'], color="g", label='bkl',kde=True, hist_kws={'alpha':0}, kde_kws={'linewidth':2})
# C:\Users\asus\AppData\Local\Temp\ipykernel_26952\1648813971.py:8: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(proportion_dict['bcc'], color="yellow", label='bcc',kde=True, hist_kws={'alpha':0}, kde_kws={'linewidth':2})
# C:\Users\asus\AppData\Local\Temp\ipykernel_26952\1648813971.py:9: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(proportion_dict['akiec'], color="orange", label='akiec',kde=True, hist_kws={'alpha':0}, kde_kws={'linewidth':2})
# C:\Users\asus\AppData\Local\Temp\ipykernel_26952\1648813971.py:10: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(proportion_dict['vasc'], color="pink", label='vasc',kde=True, hist_kws={'alpha':0}, kde_kws={'linewidth':2})
# C:\Users\asus\AppData\Local\Temp\ipykernel_26952\1648813971.py:11: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(proportion_dict['df'], color="gold", label='df',kde=True, hist_kws={'alpha':0}, kde_kws={'linewidth':2})

# %% [markdown]
# ### Approach 2
#
# #### considering only the number of white pixels

# %%
def get_number_of_whitepixels(img_path):
    n = cv2.imread(img_path)
    wp=np.sum(n == 255)
    return wp

# %%
basepath = "D:\Sakthi\dataverse_files\HAM10000_segmentations_lesion_tschandl\HAM10000_segmentations_lesion_tschandl\\"
wp_dict = {}
for cl in df_array:
    df= skin_df[skin_df['dx']==cl]
    wp_array = []
    for i, row in df.iterrows():
        wp_array.append(get_number_of_whitepixels(os.path.join(basepath, row['image_id_seg'])))
    wp_dict[cl] = wp_array

# %%
from sklearn import preprocessing

# %%
for cl in df_array:
    wp_dict[cl] =  preprocessing.normalize([wp_dict[cl]])

# %%
plt.figure(figsize=(10,7), dpi= 80)
#for cl in proportion_dict.keys():
sns.distplot(wp_dict['nv'], color="dodgerblue", label='nv',kde=True, hist_kws={'alpha':0}, kde_kws={'linewidth':2})
sns.distplot(wp_dict['mel'], color="r", label='mel',kde=True, hist_kws={'alpha':0}, kde_kws={'linewidth':2})
sns.distplot(wp_dict['bkl'], color="g", label='bkl',kde=True, hist_kws={'alpha':0}, kde_kws={'linewidth':2})
sns.distplot(wp_dict['bcc'], color="yellow", label='bcc',kde=True, hist_kws={'alpha':0}, kde_kws={'linewidth':2})
sns.distplot(wp_dict['akiec'], color="orange", label='akiec',kde=True, hist_kws={'alpha':0}, kde_kws={'linewidth':2})
sns.distplot(wp_dict['vasc'], color="pink", label='vasc',kde=True, hist_kws={'alpha':0}, kde_kws={'linewidth':2})
sns.distplot(wp_dict['df'], color="gold", label='df',kde=True, hist_kws={'alpha':0}, kde_kws={'linewidth':2})
plt.legend()
plt.show()
# Out:
# C:\Users\asus\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\asus\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\asus\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\asus\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\asus\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\asus\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\asus\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ### WP proportions and number of WP as columns in the data frame

# %%
skin_df
# Out:
#          lesion_id      image_id     dx dx_type   age     sex localization  \
# 0      HAM_0000118  ISIC_0027419    bkl   histo  80.0    male        scalp
# 1      HAM_0000118  ISIC_0025030    bkl   histo  80.0    male        scalp
# 2      HAM_0002730  ISIC_0026769    bkl   histo  80.0    male        scalp
# 3      HAM_0002730  ISIC_0025661    bkl   histo  80.0    male        scalp
# 4      HAM_0001466  ISIC_0031633    bkl   histo  75.0    male          ear
# ...            ...           ...    ...     ...   ...     ...          ...
# 10010  HAM_0002867  ISIC_0033084  akiec   histo  40.0    male      abdomen
# 10011  HAM_0002867  ISIC_0033550  akiec   histo  40.0    male      abdomen
# 10012  HAM_0002867  ISIC_0033536  akiec   histo  40.0    male      abdomen
# 10013  HAM_0000239  ISIC_0032854  akiec   histo  80.0    male         face
# 10014  HAM_0003521  ISIC_0032258    mel   histo  70.0  female         back
#
#             dataset                   image_id_seg
# 0      vidir_modern  ISIC_0027419_segmentation.png
# 1      vidir_modern  ISIC_0025030_segmentation.png
# 2      vidir_modern  ISIC_0026769_segmentation.png
# 3      vidir_modern  ISIC_0025661_segmentation.png
# 4      vidir_modern  ISIC_0031633_segmentation.png
# ...             ...                            ...
# 10010  vidir_modern  ISIC_0033084_segmentation.png
# 10011  vidir_modern  ISIC_0033550_segmentation.png
# 10012  vidir_modern  ISIC_0033536_segmentation.png
# 10013  vidir_modern  ISIC_0032854_segmentation.png
# 10014  vidir_modern  ISIC_0032258_segmentation.png
#
# [10015 rows x 9 columns]

# %%
basepath = "D:\Sakthi\dataverse_files\HAM10000_segmentations_lesion_tschandl\HAM10000_segmentations_lesion_tschandl\\"
skin_df['wp_count'] = None
skin_df['wp_proportion'] = None

# %%
skin_df
# Out:
#          lesion_id      image_id     dx dx_type   age     sex localization  \
# 0      HAM_0000118  ISIC_0027419    bkl   histo  80.0    male        scalp
# 1      HAM_0000118  ISIC_0025030    bkl   histo  80.0    male        scalp
# 2      HAM_0002730  ISIC_0026769    bkl   histo  80.0    male        scalp
# 3      HAM_0002730  ISIC_0025661    bkl   histo  80.0    male        scalp
# 4      HAM_0001466  ISIC_0031633    bkl   histo  75.0    male          ear
# ...            ...           ...    ...     ...   ...     ...          ...
# 10010  HAM_0002867  ISIC_0033084  akiec   histo  40.0    male      abdomen
# 10011  HAM_0002867  ISIC_0033550  akiec   histo  40.0    male      abdomen
# 10012  HAM_0002867  ISIC_0033536  akiec   histo  40.0    male      abdomen
# 10013  HAM_0000239  ISIC_0032854  akiec   histo  80.0    male         face
# 10014  HAM_0003521  ISIC_0032258    mel   histo  70.0  female         back
#
#             dataset                   image_id_seg wp_count wp_proportion
# 0      vidir_modern  ISIC_0027419_segmentation.png     None          None
# 1      vidir_modern  ISIC_0025030_segmentation.png     None          None
# 2      vidir_modern  ISIC_0026769_segmentation.png     None          None
# 3      vidir_modern  ISIC_0025661_segmentation.png     None          None
# 4      vidir_modern  ISIC_0031633_segmentation.png     None          None
# ...             ...                            ...      ...           ...
# 10010  vidir_modern  ISIC_0033084_segmentation.png     None          None
# 10011  vidir_modern  ISIC_0033550_segmentation.png     None          None
# 10012  vidir_modern  ISIC_0033536_segmentation.png     None          None
# 10013  vidir_modern  ISIC_0032854_segmentation.png     None          None
# 10014  vidir_modern  ISIC_0032258_segmentation.png     None          None
#
# [10015 rows x 11 columns]

# %%
#path = glob.glob(basepath+"*.png")

for i, row in skin_df.iterrows():
    path = os.path.join(basepath, row['image_id_seg'])
    n = cv2.imread(path)
    wp=np.sum(n == 255)
    bp=np.sum(n == 0)
    skin_df.loc[i,'wp_count'] = wp
    skin_df.loc[i, 'wp_proportion'] = wp/(wp+bp)

# %%
skin_df
# Out:
#          lesion_id      image_id     dx dx_type   age     sex localization  \
# 0      HAM_0000118  ISIC_0027419    bkl   histo  80.0    male        scalp
# 1      HAM_0000118  ISIC_0025030    bkl   histo  80.0    male        scalp
# 2      HAM_0002730  ISIC_0026769    bkl   histo  80.0    male        scalp
# 3      HAM_0002730  ISIC_0025661    bkl   histo  80.0    male        scalp
# 4      HAM_0001466  ISIC_0031633    bkl   histo  75.0    male          ear
# ...            ...           ...    ...     ...   ...     ...          ...
# 10010  HAM_0002867  ISIC_0033084  akiec   histo  40.0    male      abdomen
# 10011  HAM_0002867  ISIC_0033550  akiec   histo  40.0    male      abdomen
# 10012  HAM_0002867  ISIC_0033536  akiec   histo  40.0    male      abdomen
# 10013  HAM_0000239  ISIC_0032854  akiec   histo  80.0    male         face
# 10014  HAM_0003521  ISIC_0032258    mel   histo  70.0  female         back
#
#             dataset                   image_id_seg wp_count wp_proportion
# 0      vidir_modern  ISIC_0027419_segmentation.png   255999      0.316048
# 1      vidir_modern  ISIC_0025030_segmentation.png    96978      0.119726
# 2      vidir_modern  ISIC_0026769_segmentation.png   216363      0.267115
# 3      vidir_modern  ISIC_0025661_segmentation.png    64239      0.079307
# 4      vidir_modern  ISIC_0031633_segmentation.png   308802      0.381237
# ...             ...                            ...      ...           ...
# 10010  vidir_modern  ISIC_0033084_segmentation.png   439944      0.543141
# 10011  vidir_modern  ISIC_0033550_segmentation.png   161562      0.199459
# 10012  vidir_modern  ISIC_0033536_segmentation.png   237147      0.292774
# 10013  vidir_modern  ISIC_0032854_segmentation.png   411270      0.507741
# 10014  vidir_modern  ISIC_0032258_segmentation.png    24759      0.030567
#
# [10015 rows x 11 columns]

# %%
extracted_df = skin_df[['age', 'sex', 'localization','dx_type', 'wp_count', 'wp_proportion', 'dx',]]

# %%
extracted_df
# Out:
#         age     sex localization dx_type wp_count wp_proportion     dx
# 0      80.0    male        scalp   histo   255999      0.316048    bkl
# 1      80.0    male        scalp   histo    96978      0.119726    bkl
# 2      80.0    male        scalp   histo   216363      0.267115    bkl
# 3      80.0    male        scalp   histo    64239      0.079307    bkl
# 4      75.0    male          ear   histo   308802      0.381237    bkl
# ...     ...     ...          ...     ...      ...           ...    ...
# 10010  40.0    male      abdomen   histo   439944      0.543141  akiec
# 10011  40.0    male      abdomen   histo   161562      0.199459  akiec
# 10012  40.0    male      abdomen   histo   237147      0.292774  akiec
# 10013  80.0    male         face   histo   411270      0.507741  akiec
# 10014  70.0  female         back   histo    24759      0.030567    mel
#
# [10015 rows x 7 columns]

# %%
extracted_df = pd.get_dummies(extracted_df, columns = ['sex', 'localization', 'dx_type'])

# %%
extracted_df.isnull().values.any()
# Out:
# True

# %%
extracted_df.isnull().sum()
# Out:
# age                             57
# wp_count                         0
# wp_proportion                    0
# dx                               0
# sex_female                       0
# sex_male                         0
# sex_unknown                      0
# localization_abdomen             0
# localization_acral               0
# localization_back                0
# localization_chest               0
# localization_ear                 0
# localization_face                0
# localization_foot                0
# localization_genital             0
# localization_hand                0
# localization_lower extremity     0
# localization_neck                0
# localization_scalp               0
# localization_trunk               0
# localization_unknown             0
# localization_upper extremity     0
# dx_type_confocal                 0
# dx_type_consensus                0
# dx_type_follow_up                0
# dx_type_histo                    0
# dtype: int64

# %%
extracted_df = extracted_df.dropna()

# %%
extracted_df.isnull().values.any()
# Out:
# False

# %% [markdown]
# ### KNN

# %%
from sklearn.neighbors import KNeighborsClassifier

from sklearn.model_selection import train_test_split

# %%
y= extracted_df[["dx"]]
X = extracted_df.drop('dx', axis = 1)
X_train, X_test, y_train, y_test = train_test_split(
            X, y, test_size = 0.2, random_state = 1)

# %%
#Checking with KNN

clf = KNeighborsClassifier(n_neighbors = 7)
clf.fit(X_train, y_train)
print(clf.score(X_test, y_test))
# Out:
# C:\Users\asus\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:200: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# 0.6164658634538153

# %%
from sklearn.metrics import classification_report
y_pred = clf.predict(X_test)
report = classification_report(y_test, y_pred, target_names = y.dx.unique())
print(report)
# Out:
#               precision    recall  f1-score   support
#
#          bkl       0.11      0.03      0.05        62
#           nv       0.00      0.00      0.00        99
#           df       0.11      0.04      0.05       217
#          mel       0.00      0.00      0.00        40
#         vasc       0.14      0.04      0.07       225
#          bcc       0.67      0.92      0.77      1314
#        akiec       0.00      0.00      0.00        35
#
#     accuracy                           0.62      1992
#    macro avg       0.14      0.15      0.13      1992
# weighted avg       0.47      0.62      0.52      1992
# C:\Users\asus\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1327: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\asus\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1327: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\asus\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1327: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ### Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
# creating a RF classifier
clf = RandomForestClassifier(n_estimators = 100) 
 
# Training the model on the training dataset
# fit function is used to train the model using the training sets as parameters
clf.fit(X_train, y_train)
 
# performing predictions on the test dataset
y_pred = clf.predict(X_test)
# Out:
# C:\Users\asus\AppData\Local\Temp\ipykernel_16884\2241537399.py:6: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   clf.fit(X_train, y_train)

# %%
report = classification_report(y_test, y_pred, target_names = y.dx.unique())
print(report)
# Out:
#               precision    recall  f1-score   support
#
#          bkl       0.30      0.27      0.29        62
#           nv       0.18      0.19      0.18        99
#           df       0.47      0.47      0.47       217
#          mel       0.45      0.12      0.20        40
#         vasc       0.33      0.25      0.28       225
#          bcc       0.84      0.91      0.87      1314
#        akiec       0.61      0.31      0.42        35
#
#     accuracy                           0.70      1992
#    macro avg       0.45      0.36      0.39      1992
# weighted avg       0.68      0.70      0.69      1992

# %% [markdown]
# ### Gaussian Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB

# %%
clf = GaussianNB()
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
report = classification_report(y_test, y_pred, target_names = y.dx.unique())
print(report)
# Out:
#               precision    recall  f1-score   support
#
#          bkl       0.20      0.02      0.03        62
#           nv       0.00      0.00      0.00        99
#           df       0.35      0.18      0.24       217
#          mel       0.00      0.00      0.00        40
#         vasc       0.15      0.01      0.02       225
#          bcc       0.69      0.98      0.81      1314
#        akiec       0.00      0.00      0.00        35
#
#     accuracy                           0.67      1992
#    macro avg       0.20      0.17      0.16      1992
# weighted avg       0.52      0.67      0.56      1992
# C:\Users\asus\anaconda3\lib\site-packages\sklearn\utils\validation.py:1111: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\asus\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1327: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\asus\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1327: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\asus\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1327: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
